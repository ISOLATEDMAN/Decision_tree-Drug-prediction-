# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("drug200.csv")

# %%
print(data)
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df["BP"],df["Na_to_K"])
plt.title("graph b/w BP and Na_to_K")
plt.grid(True)
plt.show()

# %%
import seaborn as sns
sns.countplot(data=df,x="Cholesterol",hue="Drug")
# Out:
# <Axes: xlabel='Cholesterol', ylabel='count'>

# %%
sns.countplot(data=df,x="BP",hue="Drug")
# Out:
# <Axes: xlabel='BP', ylabel='count'>

# %%
data["Sex"] = data["Sex"].map({"F":0,"M":1})

# %%
data["BP"] = data["BP"].map({"HIGH":10,"LOW":0,"NORMAL":5})

# %%
data["Cholesterol"] = data["Cholesterol"].map({"HIGH":10,"LOW":0,"NORMAL":5})

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0  10           10   25.355  drugY
# 1     47    1   0           10   13.093  drugC
# 2     47    1   0           10   10.114  drugC
# 3     28    0   5           10    7.798  drugX
# 4     61    0   0           10   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   0           10   11.567  drugC
# 196   16    1   0           10   12.006  drugC
# 197   52    1   5           10    9.894  drugX
# 198   23    1   5            5   14.020  drugX
# 199   40    0   0            5   11.349  drugX
#
# [200 rows x 6 columns]

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0  10           10   25.355  drugY
# 1     47    1   0           10   13.093  drugC
# 2     47    1   0           10   10.114  drugC
# 3     28    0   5           10    7.798  drugX
# 4     61    0   0           10   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   0           10   11.567  drugC
# 196   16    1   0           10   12.006  drugC
# 197   52    1   5           10    9.894  drugX
# 198   23    1   5            5   14.020  drugX
# 199   40    0   0            5   11.349  drugX
#
# [200 rows x 6 columns]>

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0  10           10   25.355  drugY
# 1     47    1   0           10   13.093  drugC
# 2     47    1   0           10   10.114  drugC
# 3     28    0   5           10    7.798  drugX
# 4     61    0   0           10   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   0           10   11.567  drugC
# 196   16    1   0           10   12.006  drugC
# 197   52    1   5           10    9.894  drugX
# 198   23    1   5            5   14.020  drugX
# 199   40    0   0            5   11.349  drugX
#
# [200 rows x 6 columns]>

# %%
x = df.drop(["Drug"],axis=1).values

# %%
y = df["Drug"].values

# %%
print(x)
# Out:
# [[23.     0.    10.    10.    25.355]
#  [47.     1.     0.    10.    13.093]
#  [47.     1.     0.    10.    10.114]
#  [28.     0.     5.    10.     7.798]
#  [61.     0.     0.    10.    18.043]
#  [22.     0.     5.    10.     8.607]
#  [49.     0.     5.    10.    16.275]
#  [41.     1.     0.    10.    11.037]
#  [60.     1.     5.    10.    15.171]
#  [43.     1.     0.     5.    19.368]
#  [47.     0.     0.    10.    11.767]
#  [34.     0.    10.     5.    19.199]
#  [43.     1.     0.    10.    15.376]
#  [74.     0.     0.    10.    20.942]
#  [50.     0.     5.    10.    12.703]
#  [16.     0.    10.     5.    15.516]
#  [69.     1.     0.     5.    11.455]
#  [43.     1.    10.    10.    13.972]
#  [23.     1.     0.    10.     7.298]
#  [32.     0.    10.     5.    25.974]
#  [57.     1.     0.     5.    19.128]
#  [63.     1.     5.    10.    25.917]
#  [47.     1.     0.     5.    30.568]
#  [48.     0.     0.    10.    15.036]
#  [33.     0.     0.    10.    33.486]
# ...

# %%
print(y)
# Out:
# ['drugY' 'drugC' 'drugC' 'drugX' 'drugY' 'drugX' 'drugY' 'drugC' 'drugY'
#  'drugY' 'drugC' 'drugY' 'drugY' 'drugY' 'drugX' 'drugY' 'drugX' 'drugA'
#  'drugC' 'drugY' 'drugY' 'drugY' 'drugY' 'drugY' 'drugY' 'drugY' 'drugY'
#  'drugX' 'drugY' 'drugY' 'drugX' 'drugB' 'drugX' 'drugY' 'drugX' 'drugX'
#  'drugA' 'drugX' 'drugX' 'drugX' 'drugY' 'drugB' 'drugY' 'drugX' 'drugX'
#  'drugX' 'drugA' 'drugC' 'drugY' 'drugY' 'drugY' 'drugX' 'drugY' 'drugY'
#  'drugB' 'drugC' 'drugB' 'drugY' 'drugX' 'drugY' 'drugY' 'drugA' 'drugY'
#  'drugX' 'drugB' 'drugY' 'drugA' 'drugX' 'drugY' 'drugY' 'drugB' 'drugY'
#  'drugX' 'drugY' 'drugY' 'drugY' 'drugA' 'drugY' 'drugA' 'drugX' 'drugB'
#  'drugX' 'drugC' 'drugA' 'drugC' 'drugB' 'drugX' 'drugY' 'drugY' 'drugY'
#  'drugY' 'drugY' 'drugY' 'drugY' 'drugY' 'drugX' 'drugY' 'drugY' 'drugY'
#  'drugY' 'drugA' 'drugA' 'drugC' 'drugX' 'drugY' 'drugX' 'drugX' 'drugY'
#  'drugB' 'drugY' 'drugA' 'drugX' 'drugX' 'drugX' 'drugX' 'drugY' 'drugX'
# ...

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=12)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion='entropy')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = model.predict(x_test)

# %%
print(y_pred)
# Out:
# ['drugY' 'drugX' 'drugY' 'drugY' 'drugX' 'drugY' 'drugA' 'drugX' 'drugY'
#  'drugC' 'drugX' 'drugY' 'drugX' 'drugY' 'drugY' 'drugA' 'drugB' 'drugX'
#  'drugX' 'drugB' 'drugY' 'drugY' 'drugA' 'drugX' 'drugX' 'drugX' 'drugX'
#  'drugY' 'drugB' 'drugB' 'drugY' 'drugY' 'drugX' 'drugY' 'drugY' 'drugX'
#  'drugY' 'drugC' 'drugC' 'drugX' 'drugY' 'drugC' 'drugY' 'drugX' 'drugB'
#  'drugY' 'drugY' 'drugY' 'drugX' 'drugY']

# %%
print(y_test)
# Out:
# ['drugY' 'drugX' 'drugY' 'drugY' 'drugX' 'drugY' 'drugA' 'drugX' 'drugY'
#  'drugC' 'drugX' 'drugY' 'drugX' 'drugY' 'drugY' 'drugB' 'drugB' 'drugX'
#  'drugX' 'drugB' 'drugY' 'drugY' 'drugA' 'drugX' 'drugX' 'drugX' 'drugX'
#  'drugY' 'drugB' 'drugB' 'drugY' 'drugY' 'drugX' 'drugY' 'drugY' 'drugX'
#  'drugY' 'drugC' 'drugC' 'drugX' 'drugY' 'drugC' 'drugY' 'drugX' 'drugB'
#  'drugY' 'drugY' 'drugY' 'drugX' 'drugY']

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)

# %%
print(cm)
# Out:
# [[ 2  0  0  0  0]
#  [ 1  5  0  0  0]
#  [ 0  0  4  0  0]
#  [ 0  0  0 16  0]
#  [ 0  0  0  0 22]]

# %%
from sklearn.metrics import accuracy_score,precision_score,classification_report
sc=accuracy_score(y_pred,y_test)
print(sc)
# Out:
# 0.98

# %%
precision = precision_score(y_test, y_pred, average='weighted')

# %%
print(precision)
# Out:
# 0.9866666666666666

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        drugA       0.67      1.00      0.80         2
#        drugB       1.00      0.83      0.91         6
#        drugC       1.00      1.00      1.00         4
#        drugX       1.00      1.00      1.00        16
#        drugY       1.00      1.00      1.00        22
#
#     accuracy                           0.98        50
#    macro avg       0.93      0.97      0.94        50
# weighted avg       0.99      0.98      0.98        50
